# %%
# import numpy as np

# %%
 class DepartmentReport():
    import numpy as np
    def add_revenue(self, amount):
        """
        Метод для добавления выручки отдела в список revenues.
        Если атрибута revenues ещё не существует, метод должен создавать пустой список перед добавлением выручки.
        """
        if not hasattr(self, 'revenues'):  
            self.revenues = []  
        # Добавим текущую выручку  
        self.revenues.append(amount)  
    
    def average_revenue(self):
        """
        Метод возвращает среднюю выручку по отделам.
        """
        mean_revenues  =  np.mean(self.revenues) 
        return mean_revenues
 
report = DepartmentReport()
report.add_revenue(1_000_000)
report.add_revenue(400_000)
print(report.revenues)
# => [1000000, 400000]
print(report.average_revenue)
# => 700000.0
# Out:
# [1000000, 400000]
# <bound method DepartmentReport.average_revenue of <__main__.DepartmentReport object at 0x0000015830D2ACA0>>

# %%
class DepartmentReport():
    import numpy as np
    def __init__(self,company):
        """
        Метод инициализации класса. 
        Создаёт атрибуты revenues и company
        """
        self.revenues = []  
        self.company = company
    
    def add_revenue(self, amount):
        """
        Метод для добавления выручки отдела в список revenues.
        Если атрибута revenues ещё не существует, метод должен создавать пустой список перед добавлением выручки.
        """
        self.revenues.append(amount)
    
    def average_revenue(self):
        """
        Вычисляет average_revenue — среднюю выручку по отделам — округляя до целого.
        Метод возвращает строку в формате:
        'Average department revenue for <company>: <average_revenue>'
        """
        mean_revenues = round(np.mean(self.revenues))
        average = "Average department revenue for {0}: {1}".format(self.company, mean_revenues)
        return average

report = DepartmentReport("Danon")
report.add_revenue(1_000_000)
report.add_revenue(400_000)

print(report.average_revenue())
# => Average department revenue for Danon: 700000

# %%
class User():
    def __init__(self, email, password, balance):  
        self.email = email  
        self.password = password  
        self.balance = balance  
     
    def login(self, email, password):   
        if  self.email == email and self.password == password:
            # print('True')
            return True
        else:
            # print('False')
            return False
            
    def update_balance(self, amount):
        self.balance +=  amount
        return self.balance
    
user = User("gosha@roskino.org", "qwerty", 20_000)
user.login("gosha@roskino.org", "qwerty123")
# => False
user.login("gosha@roskino.org", "qwerty")
# => True
user.update_balance(200)
user.update_balance(-500)
print(user.balance)
# => 19700

# %%
import statistics 
import numpy as np
  
class IntDataFrame():  
    def __init__(self, list, fill_value=0):  
        # Инициализируем атрибуты  
        self.list = list  
        self.fill_value = fill_value  
        # Заполним пропуски  
        self.fill_missed()  
        # Конвертируем все элементы в числа  
        self.to_int()  
          
    def fill_missed(self):  
        for i, value in enumerate(self.list):  
            if value is None or value == '':  
                self.column[i] = self.fill_value  
                  
    def to_int(self):  
        self.list = [int(value) for value in self.list]  
      
    def median(self):  
        return statistics.median(self.list)  
      
    def mean(self):  
        return statistics.mean(self.list)  
      
    def deviation(self):  
        return statistics.stdev(self.list)  
    
    def count(self):  
        count = 0
        for elem in self.list:
            if elem:
                count+=1                       
        return count
    
    def unique(self):
        return len(set(self.list))

# %%
df = IntDataFrame([4.7, 4, 3, 0, 2.4, 0.3, 4])

df.count()
# => 5
df.unique()
# => 4

# %%
import pickle  
from datetime import datetime  
from os import path  
  
class Dumper():  
    def __init__(self, archive_dir="archive/"):  
        self.archive_dir = archive_dir  
          
    def dump(self, data):  
        # Библиотека pickle позволяет доставать и класть объекты в файл  
        with open(self.get_file_name(), 'wb') as file:  
            pickle.dump(data, file)  
              
    def load_for_day(self, day):  
        file_name = path.join(self.archive_dir, day + ".pkl")   
        with open(file_name, 'rb') as file:  
            sets = pickle.load(file)  
        return sets  
          
    # возвращает корректное имя для файла   
    def get_file_name(self):   
        today = datetime.now().strftime("%y-%m-%d")   
        return path.join(self.archive_dir, today + ".pkl")  
      
      
# Пример использования  
  
data = {  
    'perfomance': [10, 20, 10],  
    'clients': {"Romashka": 10, "Vector": 34}  
}  
  
  
dumper = Dumper()  
  
# Сохраним данные  
dumper.dump(data)  
  
# Восстановим для сегодняшней даты  
file_name = datetime.now().strftime("%y-%m-%d")
restored_data = dumper.load_for_day(file_name)
print(restored_data)

# %%
import pandas as pd
class OwnLogger():    
    def __init__(self, message, level ):
        self.message = message
        self.level = level
        self.mess_df = pd.DataFrame({
        'info': [],
        'warning': [],
        'error': [],    
        })
        
    def log(self, message, level):
        if level in self.mess_df.columns:
            self.mess_df[level].append(message)
                        

logger = OwnLogger()
logger.log("System started", "info")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [8], in <module>
#      13         if level is self.mess_df.columns:
#      14             self.mess_df[level].append(message)
# ---> 18 logger = OwnLogger()
#      19 logger.log("System started", "info")
#
# TypeError: __init__() missing 2 required positional arguments: 'message' and 'level'
