# %%
a = 7
b = 3
c = a + b

# %%
print(c)
# Out:
# 10

# %%
import matplotlib.pyplot as plt

# %%
x_1 = [-2, -1, 0, 1, 2]
y = [4, 1, 0, 1, 4]
x_2 = [0, 1, 2, 3, 4]

# %%
plt.plot(x_1,y)
plt.plot(x_2,y)

# %% [markdown]
# # Заголовок 1

# %% [markdown]
# ## Заголовок 2

# %% [markdown]
# **отонокак**

# %% [markdown]
# *отож*

# %% [markdown]
# | Это  | таблица  |
# |------|----------|
# |да    |   нет    |
